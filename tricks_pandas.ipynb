# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.2'

# %%
pd.show_versions()
# Out:
# C:\Users\Otaku\AppData\Local\Programs\Python\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 965ceca9fd796940050d6fc817707bba1c4f9bff
# python           : 3.11.3.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.22621
# machine          : AMD64
# processor        : Intel64 Family 6 Model 140 Stepping 2, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 2.0.2
# numpy            : 1.24.3
# pytz             : 2023.3
# dateutil         : 2.8.2
# setuptools       : 65.5.0
# pip              : 23.1.2
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# ...

# %%
#create an example dataframe
nor=pd.DataFrame({'col one':[100,200], 'col two':[300,400]})

# %%
nor
# Out:
#    col one  col two
# 0      100      300
# 1      200      400

# %%
nor=nor.rename({'col one':'col_one','col two':'col_two'},axis='columns')

# %%
nor
# Out:
#    col_one  col_two
# 0      100      300
# 1      200      400

# %%
nor=nor.columns.str.replace('_',' ')

# %%
nor.columns=['col_one','col_two']

# %%
nor
# Out:
# Index(['col one', 'col two'], dtype='object')

# %%
nor.add_prefix('X_')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 nor.add_prefix('X_')
#
# AttributeError: 'Index' object has no attribute 'add_prefix'

# %%
#using random 
import pandas as pd
import numpy as np
auto=pd.DataFrame(np.random.rand(4,8))

# %%
auto
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.528262  0.832883  0.991225  0.438569  0.912832  0.696499  0.054849
# 1  0.439913  0.297101  0.383636  0.124314  0.374358  0.358351  0.478720
# 2  0.905744  0.465520  0.662612  0.366713  0.063522  0.035877  0.187688
# 3  0.261116  0.173708  0.145551  0.290644  0.079157  0.821668  0.107153
#
#           7
# 0  0.387434
# 1  0.791377
# 2  0.808646
# 3  0.011306

# %%
#giving coulmns name
auto=pd.DataFrame(np.random.rand(7,13), columns=list('abcdefghijlmn'))

# %%
auto
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.938376  0.764763  0.484661  0.727897  0.656622  0.943814  0.283713
# 1  0.036517  0.027454  0.000567  0.953770  0.939733  0.955930  0.481719
# 2  0.878431  0.244853  0.918068  0.086514  0.380647  0.693359  0.867046
# 3  0.240382  0.532867  0.918842  0.739546  0.810350  0.704737  0.879530
# 4  0.903108  0.815517  0.180890  0.912401  0.648617  0.495163  0.605870
# 5  0.094408  0.385583  0.202278  0.456698  0.618326  0.100025  0.917908
# 6  0.756439  0.425080  0.449843  0.805364  0.056141  0.835303  0.709313
#
#           h         i         j         l         m         n
# 0  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# 4  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484
# ...

# %%
#renameing the columns
auto=auto.rename({'a':'col one','b':'col two','c':'col three','c':'col four','d':'col five','e':'col six','f':'col seven','g':'col eight'},axis='columns')

# %%
auto
# Out:
#     col one   col two  col four  col five   col six  col seven  col eight  \
# 0  0.938376  0.764763  0.484661  0.727897  0.656622   0.943814   0.283713
# 1  0.036517  0.027454  0.000567  0.953770  0.939733   0.955930   0.481719
# 2  0.878431  0.244853  0.918068  0.086514  0.380647   0.693359   0.867046
# 3  0.240382  0.532867  0.918842  0.739546  0.810350   0.704737   0.879530
# 4  0.903108  0.815517  0.180890  0.912401  0.648617   0.495163   0.605870
# 5  0.094408  0.385583  0.202278  0.456698  0.618326   0.100025   0.917908
# 6  0.756439  0.425080  0.449843  0.805364  0.056141   0.835303   0.709313
#
#           h         i         j         l         m         n
# 0  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# 4  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484
# ...

# %%
auto.columns=auto.columns.str.replace(' ','_')

# %%
auto
# Out:
#     col_one   col_two  col_four  col_five   col_six  col_seven  col_eight  \
# 0  0.938376  0.764763  0.484661  0.727897  0.656622   0.943814   0.283713
# 1  0.036517  0.027454  0.000567  0.953770  0.939733   0.955930   0.481719
# 2  0.878431  0.244853  0.918068  0.086514  0.380647   0.693359   0.867046
# 3  0.240382  0.532867  0.918842  0.739546  0.810350   0.704737   0.879530
# 4  0.903108  0.815517  0.180890  0.912401  0.648617   0.495163   0.605870
# 5  0.094408  0.385583  0.202278  0.456698  0.618326   0.100025   0.917908
# 6  0.756439  0.425080  0.449843  0.805364  0.056141   0.835303   0.709313
#
#           h         i         j         l         m         n
# 0  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# 4  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484
# ...

# %%
auto.add_prefix('X_')
# Out:
#    X_col_one  X_col_two  X_col_four  X_col_five  X_col_six  X_col_seven  \
# 0   0.938376   0.764763    0.484661    0.727897   0.656622     0.943814
# 1   0.036517   0.027454    0.000567    0.953770   0.939733     0.955930
# 2   0.878431   0.244853    0.918068    0.086514   0.380647     0.693359
# 3   0.240382   0.532867    0.918842    0.739546   0.810350     0.704737
# 4   0.903108   0.815517    0.180890    0.912401   0.648617     0.495163
# 5   0.094408   0.385583    0.202278    0.456698   0.618326     0.100025
# 6   0.756439   0.425080    0.449843    0.805364   0.056141     0.835303
#
#    X_col_eight       X_h       X_i       X_j       X_l       X_m       X_n
# 0     0.283713  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1     0.481719  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2     0.867046  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3     0.879530  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# ...

# %%
auto.add_suffix('_Y')
# Out:
#    col_one_Y  col_two_Y  col_four_Y  col_five_Y  col_six_Y  col_seven_Y  \
# 0   0.938376   0.764763    0.484661    0.727897   0.656622     0.943814
# 1   0.036517   0.027454    0.000567    0.953770   0.939733     0.955930
# 2   0.878431   0.244853    0.918068    0.086514   0.380647     0.693359
# 3   0.240382   0.532867    0.918842    0.739546   0.810350     0.704737
# 4   0.903108   0.815517    0.180890    0.912401   0.648617     0.495163
# 5   0.094408   0.385583    0.202278    0.456698   0.618326     0.100025
# 6   0.756439   0.425080    0.449843    0.805364   0.056141     0.835303
#
#    col_eight_Y       h_Y       i_Y       j_Y       l_Y       m_Y       n_Y
# 0     0.283713  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1     0.481719  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2     0.867046  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3     0.879530  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# ...

# %%
# 4.) reverse row order
auto.head()
# Out:
#     col_one   col_two  col_four  col_five   col_six  col_seven  col_eight  \
# 0  0.938376  0.764763  0.484661  0.727897  0.656622   0.943814   0.283713
# 1  0.036517  0.027454  0.000567  0.953770  0.939733   0.955930   0.481719
# 2  0.878431  0.244853  0.918068  0.086514  0.380647   0.693359   0.867046
# 3  0.240382  0.532867  0.918842  0.739546  0.810350   0.704737   0.879530
# 4  0.903108  0.815517  0.180890  0.912401  0.648617   0.495163   0.605870
#
#           h         i         j         l         m         n
# 0  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# 4  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484

# %%
auto.loc[::-1].head   #reverseing the total data
# Out:
# <bound method NDFrame.head of     col_one   col_two  col_four  col_five   col_six  col_seven  col_eight  \
# 6  0.756439  0.425080  0.449843  0.805364  0.056141   0.835303   0.709313
# 5  0.094408  0.385583  0.202278  0.456698  0.618326   0.100025   0.917908
# 4  0.903108  0.815517  0.180890  0.912401  0.648617   0.495163   0.605870
# 3  0.240382  0.532867  0.918842  0.739546  0.810350   0.704737   0.879530
# 2  0.878431  0.244853  0.918068  0.086514  0.380647   0.693359   0.867046
# 1  0.036517  0.027454  0.000567  0.953770  0.939733   0.955930   0.481719
# 0  0.938376  0.764763  0.484661  0.727897  0.656622   0.943814   0.283713
#
#           h         i         j         l         m         n
# 6  0.501085  0.078414  0.980458  0.212475  0.967017  0.997365
# 5  0.283074  0.994031  0.769534  0.851612  0.661079  0.558423
# 4  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# ...

# %%
auto.loc[::-1].reset_index(drop=True).head() #reseting the index values
# Out:
#     col_one   col_two  col_four  col_five   col_six  col_seven  col_eight  \
# 0  0.756439  0.425080  0.449843  0.805364  0.056141   0.835303   0.709313
# 1  0.094408  0.385583  0.202278  0.456698  0.618326   0.100025   0.917908
# 2  0.903108  0.815517  0.180890  0.912401  0.648617   0.495163   0.605870
# 3  0.240382  0.532867  0.918842  0.739546  0.810350   0.704737   0.879530
# 4  0.878431  0.244853  0.918068  0.086514  0.380647   0.693359   0.867046
#
#           h         i         j         l         m         n
# 0  0.501085  0.078414  0.980458  0.212475  0.967017  0.997365
# 1  0.283074  0.994031  0.769534  0.851612  0.661079  0.558423
# 2  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# 4  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243

# %%
auto.loc[:,::-1].head
# Out:
# <bound method NDFrame.head of           n         m         l         j         i         h  col_eight  \
# 0  0.326633  0.446949  0.329636  0.540845  0.688485  0.354260   0.283713
# 1  0.135669  0.374551  0.746296  0.869342  0.252207  0.003616   0.481719
# 2  0.003243  0.655059  0.862214  0.315614  0.446896  0.446644   0.867046
# 3  0.062093  0.713732  0.468201  0.845583  0.320287  0.005547   0.879530
# 4  0.485484  0.408058  0.434984  0.794316  0.874326  0.795977   0.605870
# 5  0.558423  0.661079  0.851612  0.769534  0.994031  0.283074   0.917908
# 6  0.997365  0.967017  0.212475  0.980458  0.078414  0.501085   0.709313
#
#    col_seven   col_six  col_five  col_four   col_two   col_one
# 0   0.943814  0.656622  0.727897  0.484661  0.764763  0.938376
# 1   0.955930  0.939733  0.953770  0.000567  0.027454  0.036517
# 2   0.693359  0.380647  0.086514  0.918068  0.244853  0.878431
# 3   0.704737  0.810350  0.739546  0.918842  0.532867  0.240382
# ...

# %%
auto.dtypes
# Out:
# col_one      float64
# col_two      float64
# col_four     float64
# col_five     float64
# col_six      float64
# col_seven    float64
# col_eight    float64
# h            float64
# i            float64
# j            float64
# l            float64
# m            float64
# n            float64
# dtype: object

# %%
auto.select_dtypes(include='number').head()
# Out:
#     col_one   col_two  col_four  col_five   col_six  col_seven  col_eight  \
# 0  0.938376  0.764763  0.484661  0.727897  0.656622   0.943814   0.283713
# 1  0.036517  0.027454  0.000567  0.953770  0.939733   0.955930   0.481719
# 2  0.878431  0.244853  0.918068  0.086514  0.380647   0.693359   0.867046
# 3  0.240382  0.532867  0.918842  0.739546  0.810350   0.704737   0.879530
# 4  0.903108  0.815517  0.180890  0.912401  0.648617   0.495163   0.605870
#
#           h         i         j         l         m         n
# 0  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# 4  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484

# %%
auto.select_dtypes(include='object').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
auto.select_dtypes(exclude='object').head()
# Out:
#     col_one   col_two  col_four  col_five   col_six  col_seven  col_eight  \
# 0  0.938376  0.764763  0.484661  0.727897  0.656622   0.943814   0.283713
# 1  0.036517  0.027454  0.000567  0.953770  0.939733   0.955930   0.481719
# 2  0.878431  0.244853  0.918068  0.086514  0.380647   0.693359   0.867046
# 3  0.240382  0.532867  0.918842  0.739546  0.810350   0.704737   0.879530
# 4  0.903108  0.815517  0.180890  0.912401  0.648617   0.495163   0.605870
#
#           h         i         j         l         m         n
# 0  0.354260  0.688485  0.540845  0.329636  0.446949  0.326633
# 1  0.003616  0.252207  0.869342  0.746296  0.374551  0.135669
# 2  0.446644  0.446896  0.315614  0.862214  0.655059  0.003243
# 3  0.005547  0.320287  0.845583  0.468201  0.713732  0.062093
# 4  0.795977  0.874326  0.794316  0.434984  0.408058  0.485484

# %%
auto.select_dtypes(exclude='number').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#changing the datatype
auto.astype({'col_one':'int','col_two':'int'}).dtypes
# Out:
# col_one        int32
# col_two        int32
# col_four     float64
# col_five     float64
# col_six      float64
# col_seven    float64
# col_eight    float64
# h            float64
# i            float64
# j            float64
# l            float64
# m            float64
# n            float64
# dtype: object

# %%
import pandas as pd

# %%
puu=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv",index_col='Responseld')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 puu=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv",index_col='Responseld')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
puu
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
puu.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
cols=['ResponseId','MainBranch','Country','LanguageHaveWorkedWith','Age','Gender','Accessibility','ConvertedCompYearly','NEWOtherComms']

# %%
smaller_puu=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv",usecols=cols)

# %%
smaller_puu.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ResponseId              83439 non-null  int64
#  1   MainBranch              83439 non-null  object
#  2   Country                 83439 non-null  object
#  3   LanguageHaveWorkedWith  82357 non-null  object
#  4   NEWOtherComms           82828 non-null  object
#  5   Age                     82407 non-null  object
#  6   Gender                  82286 non-null  object
#  7   Accessibility           77603 non-null  object
#  8   ConvertedCompYearly     46844 non-null  float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 42.5 MB

# %%
smaller_puu
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                                  Country  \
# 0                                               Slovakia
# ...

# %%
fuller_puu=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv")

# %%
fuller_puu
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
fuller_puu.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
fu
