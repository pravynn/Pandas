# %%
import pandas as pd

# %%
data1=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv")

# %%
data1
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1.sort_values(by='Country',ascending=False)
# Out:
#        ResponseId                              MainBranch  \
# 13395       13396          I am a developer by profession
# 29070       29071          I am a developer by profession
# 31652       31653          I am a developer by profession
# 80996       80997             I code primarily as a hobby
# 46797       46798          I am a developer by profession
# ...           ...                                     ...
# 40223       40224  I am a student who is learning to code
# 31596       31597          I am a developer by profession
# 40402       40403          I am a developer by profession
# 31504       31505  I am a student who is learning to code
# 37765       37766          I am a developer by profession
#
#                                               Employment      Country  \
# 13395                 Not employed, but looking for work     Zimbabwe
# 29070                                 Employed full-time     Zimbabwe
# ...

# %%
data1.sort_values(by=['Country','YearsCode'],ascending=[True,False],inplace=True)

# %%
data1[['Country','YearsCode']].head(50)
# Out:
#            Country           YearsCode
# 37549  Afghanistan  More than 50 years
# 38693  Afghanistan  More than 50 years
# 39471  Afghanistan  More than 50 years
# 51791  Afghanistan    Less than 1 year
# 55150  Afghanistan    Less than 1 year
# 62690  Afghanistan    Less than 1 year
# 67508  Afghanistan    Less than 1 year
# 72314  Afghanistan    Less than 1 year
# 77979  Afghanistan    Less than 1 year
# 31504  Afghanistan                   9
# 11131  Afghanistan                   8
# 11377  Afghanistan                   8
# 14882  Afghanistan                   8
# 37765  Afghanistan                   8
# 5100   Afghanistan                   7
# 11461  Afghanistan                   7
# 17486  Afghanistan                   7
# 26034  Afghanistan                   7
# 26955  Afghanistan                   7
# 44640  Afghanistan                   7
# 51428  Afghanistan                   7
# 65399  Afghanistan                   7
# 72548  Afghanistan                   7
# ...

# %%
data1['YearsCode'] = pd.to_numeric(data1['YearsCode'], errors='coerce')

# %%
data1['YearsCode'].nsmallest(10)
# Out:
# 68426    1.0
# 72595    1.0
# 75436    1.0
# 78757    1.0
# 6763     1.0
# 53444    1.0
# 81063    1.0
# 20015    1.0
# 63285    1.0
# 52341    1.0
# Name: YearsCode, dtype: float64

# %%
data1.nsmallest(10,'YearsCode')
# Out:
#        ResponseId                              MainBranch  \
# 68426       68427                           None of these
# 72595       72596          I am a developer by profession
# 75436       75437                           None of these
# 78757       78758          I am a developer by profession
# 6763         6764  I am a student who is learning to code
# 53444       53445  I am a student who is learning to code
# 81063       81064  I am a student who is learning to code
# 20015       20016  I am a student who is learning to code
# 63285       63286             I code primarily as a hobby
# 52341       52342                           None of these
#
#                                Employment      Country US_State UK_Country  \
# 68426                  Employed full-time  Afghanistan      NaN        NaN
# 72595                  Employed full-time  Afghanistan      NaN        NaN
# 75436                  Student, full-time  Afghanistan      NaN        NaN
# ...
