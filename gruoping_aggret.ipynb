# %%
import pandas as pd

# %%
dat2=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv")

# %%
dat2.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
dat2['YearsCode'] = pd.to_numeric(dat2['YearsCode'], errors='coerce')

# %%
dat2.nsmallest(10, 'YearsCode')
# Out:
#      ResponseId                              MainBranch  \
# 54           55  I am a student who is learning to code
# 80           81          I am a developer by profession
# 136         137          I am a developer by profession
# 215         216          I am a developer by profession
# 218         219  I am a student who is learning to code
# 555         556  I am a student who is learning to code
# 577         578          I am a developer by profession
# 640         641  I am a student who is learning to code
# 667         668  I am a student who is learning to code
# 765         766  I am a student who is learning to code
#
#                                             Employment  \
# 54                                  Student, full-time
# 80   Independent contractor, freelancer, or self-em...
# 136                                 Employed full-time
# 215                                 Student, part-time
# 218                                 Student, part-time
# ...

# %%
dat2['YearsCode'].median()
# Out:
# 10.0

# %%
dat2.groupby('MainBranch')

# %%
print(dat2.groupby('MainBranch').groups)
# Out:
# {'I am a developer by profession': [0, 3, 4, 8, 9, 10, 11, 12, 16, 17, 20, 23, 24, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 40, 44, 45, 48, 50, 51, 52, 53, 55, 56, 57, 59, 60, 66, 67, 68, 69, 71, 72, 74, 75, 77, 79, 80, 83, 84, 85, 86, 87, 88, 89, 90, 92, 93, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 108, 109, 110, 111, 113, 114, 116, 117, 118, 119, 121, 122, 123, 125, 128, 129, 130, 131, 134, 135, 136, 137, 138, 139, 141, 142, 143, 144, 145, 146, 150, ...], 'I am a student who is learning to code': [1, 5, 7, 13, 15, 21, 22, 38, 39, 49, 54, 73, 78, 82, 94, 115, 147, 149, 169, 197, 200, 204, 216, 218, 220, 221, 241, 247, 248, 255, 257, 266, 277, 283, 287, 291, 293, 297, 303, 307, 310, 320, 331, 340, 343, 388, 391, 394, 395, 407, 411, 418, 423, 427, 431, 445, 446, 447, 453, 461, 466, 479, 484, 531, 542, 551, 553, 555, 557, 558, 568, 573, 593, 604, 622, 623, 630, 633, 636, 640, 641, 643, 647, 665, 667, 674, 685, 695, 699, 704, 706, 721, 737, 740, 746, 747, 763, 765, 766, 835
# ...

# %%
gk=dat2.groupby('MainBranch')

# %%
gk.first()
# Out:
#                                                     ResponseId  \
# MainBranch
# I am a developer by profession                               1
# I am a student who is learning to code                       2
# I am not primarily a developer, but I write cod...           3
# I code primarily as a hobby                                  7
# I used to be a developer by profession, but no ...          15
# None of these                                              165
#
#                                                                                            Employment  \
# MainBranch
# I am a developer by profession                      Independent contractor, freelancer, or self-em...
# I am a student who is learning to code                                             Student, full-time
# I am not primarily a developer, but I write cod...                                 Student, full-time
# ...

# %%
dat2['ConvertedCompYearly'].sum()
# Out:
# 5547554706.0

# %%
dat2.describe()
# Out:
#          ResponseId     YearsCode     CompTotal  ConvertedCompYearly
# count  83439.000000  79982.000000  4.718300e+04         4.684400e+04
# mean   41720.000000     12.485722  2.119407e+69         1.184262e+05
# std    24086.908893      9.626184  4.603702e+71         5.272944e+05
# min        1.000000      1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000      5.000000  1.600000e+04         2.702500e+04
# 50%    41720.000000     10.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000     17.000000  1.400000e+05         1.000000e+05
# max    83439.000000     50.000000  1.000000e+74         4.524131e+07

# %%
dat2['ConvertedCompYearly'].count()
# Out:
# 46844

# %%
dat2['Country']
# Out:
# 0                                                 Slovakia
# 1                                              Netherlands
# 2                                       Russian Federation
# 3                                                  Austria
# 4        United Kingdom of Great Britain and Northern I...
#                                ...
# 83434                             United States of America
# 83435                                                Benin
# 83436                             United States of America
# 83437                                               Canada
# 83438                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
dat2['Country'].value_counts(normalize=True)
# Out:
# Country
# United States of America                                0.183224
# India                                                   0.125972
# Germany                                                 0.067415
# United Kingdom of Great Britain and Northern Ireland    0.053632
# Canada                                                  0.036098
#                                                           ...
# Saint Kitts and Nevis                                   0.000012
# Dominica                                                0.000012
# Saint Vincent and the Grenadines                        0.000012
# Tuvalu                                                  0.000012
# Papua New Guinea                                        0.000012
# Name: proportion, Length: 181, dtype: float64

# %%
country_grp=dat2.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
#using filter to sort the data's
filt= dat2['Country'] =='Canada'
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437     True
# 83438    False
# Name: Country, Length: 83439, dtype: bool

# %%
dat2.loc[filt]['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          1284
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        449
# Some college/university study without earning a degree                                 415
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     298
# Associate degree (A.A., A.S., etc.)                                                    182
# Primary/elementary school                                                              155
# Something else                                                                         104
# Other doctoral degree (Ph.D., Ed.D., etc.)                                              89
# Professional degree (JD, MD, etc.)                                                      25
# Name: count, dtype: int64

# %%
country_grp['EdLevel'].value_counts().head(50)
# Out:
# Country      EdLevel
# Afghanistan  Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           21
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     10
#              Primary/elementary school                                                               8
#              Some college/university study without earning a degree                                  6
#              Something else                                                                          6
#              Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         5
#              Professional degree (JD, MD, etc.)                                                      4
#              Associate degree (A.A., A.S., etc.)                                                     1
# Albania      Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           24
# ...

# %%
fl2=dat2['Gender'] == 'Woman'
fl2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: Gender, Length: 83439, dtype: bool

# %%
dat2.loc[fl2]['Age1stCode'].value_counts(normalize=True)
# Out:
# Age1stCode
# 11 - 17 years           0.431458
# 18 - 24 years           0.340394
# 5 - 10 years            0.093986
# 25 - 34 years           0.084003
# 35 - 44 years           0.020940
# Younger than 5 years    0.017044
# 45 - 54 years           0.006818
# 55 - 64 years           0.003652
# Older than 64 years     0.001704
# Name: proportion, dtype: float64

# %%
country_grp['ConvertedCompYearly'].median().loc['Afghanistan']
# Out:
# 9792.0

# %%
#viewing the mean and median country wise
country_grp['ConvertedCompYearly'].agg(['median','mean']).tail(40)
# Out:
#                                                       median           mean
# Country
# Senegal                                              15816.0   15370.500000
# Serbia                                               31944.0  129877.872727
# Sierra Leone                                             NaN            NaN
# Singapore                                            64548.0  109176.479452
# Slovakia                                             37620.0   45764.394161
# Slovenia                                             40860.0   56961.792208
# Somalia                                               9600.0    9600.000000
# South Africa                                         46935.0   56919.556150
# South Korea                                          44160.0  107689.129412
# Spain                                                41077.0   79179.841546
# Sri Lanka                                            11544.0   12937.417647
# ...

# %%
#viewing the mean and median for particular country
country_grp['ConvertedCompYearly'].agg(['median','mean']).loc['Canada']
# Out:
# median     75631.000000
# mean      135732.563006
# Name: Canada, dtype: float64

# %%
fl=dat2['Country']== 'India'
fl
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: Country, Length: 83439, dtype: bool

# %%
dat2.loc[fl]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).value_counts(normalize=True)
# Out:
# LanguageHaveWorkedWith
# 1       0.071823
# 4       0.066298
# 3       0.055249
# 2       0.038674
# 0       0.038674
#           ...
# 295     0.005525
# 2713    0.005525
# 1423    0.005525
# 61      0.005525
# 173     0.005525
# Name: proportion, Length: 96, dtype: float64

# %%
country_respondents=dat2['Country'].value_counts()

# %%
country_respondents
# Out:
# Country
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: count, Length: 181, dtype: int64

# %%
country_uses_python=country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
python_dat2=pd.concat([country_respondents,country_uses_python],axis='columns',sort=False)

# %%
python_dat2
# Out:
#                                                     count  \
# Country
# United States of America                            15288
# India                                               10511
# Germany                                              5625
# United Kingdom of Great Britain and Northern Ir...   4475
# Canada                                               3012
# ...                                                   ...
# Saint Kitts and Nevis                                   1
# Dominica                                                1
# Saint Vincent and the Grenadines                        1
# Tuvalu                                                  1
# Papua New Guinea                                        1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
python_dat2.rename(columns={'count':'country_respondents','LanguageHaveWorkedWith':'NumknowsPython'},inplace=True)

# %%
python_dat2
# Out:
#                                                     country_respondents  \
# Country
# United States of America                                          15288
# India                                                             10511
# Germany                                                            5625
# United Kingdom of Great Britain and Northern Ir...                 4475
# Canada                                                             3012
# ...                                                                 ...
# Saint Kitts and Nevis                                                 1
# Dominica                                                              1
# Saint Vincent and the Grenadines                                      1
# Tuvalu                                                                1
# Papua New Guinea                                                      1
#
#                                                     NumknowsPython
# Country
# ...

# %%
python_dat2
# Out:
#                                                     country_respondents  \
# Country
# United States of America                                          15288
# India                                                             10511
# Germany                                                            5625
# United Kingdom of Great Britain and Northern Ir...                 4475
# Canada                                                             3012
# ...                                                                 ...
# Saint Kitts and Nevis                                                 1
# Dominica                                                              1
# Saint Vincent and the Grenadines                                      1
# Tuvalu                                                                1
# Papua New Guinea                                                      1
#
#                                                     NumknowsPython
# Country
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
dat2
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
python_dat2['pctknowsPython']=(python_dat2['NumknowsPython']/python_dat2['country_respondents'])*100

# %%
python_dat2
# Out:
#                                                     country_respondents  \
# Country
# United States of America                                          15288
# India                                                             10511
# Germany                                                            5625
# United Kingdom of Great Britain and Northern Ir...                 4475
# Canada                                                             3012
# ...                                                                 ...
# Saint Kitts and Nevis                                                 1
# Dominica                                                              1
# Saint Vincent and the Grenadines                                      1
# Tuvalu                                                                1
# Papua New Guinea                                                      1
#
#                                                     NumknowsPython  \
# Country
# ...

# %%
python_dat2
# Out:
#                                                     country_respondents  \
# Country
# United States of America                                          15288
# India                                                             10511
# Germany                                                            5625
# United Kingdom of Great Britain and Northern Ir...                 4475
# Canada                                                             3012
# ...                                                                 ...
# Saint Kitts and Nevis                                                 1
# Dominica                                                              1
# Saint Vincent and the Grenadines                                      1
# Tuvalu                                                                1
# Papua New Guinea                                                      1
#
#                                                     NumknowsPython  \
# Country
# ...

# %%
python_dat2=python_dat2.drop('pctknowspython', axis=1)

# %%
python_dat2
# Out:
#                                                     country_respondents  \
# Country
# United States of America                                          15288
# India                                                             10511
# Germany                                                            5625
# United Kingdom of Great Britain and Northern Ir...                 4475
# Canada                                                             3012
# ...                                                                 ...
# Saint Kitts and Nevis                                                 1
# Dominica                                                              1
# Saint Vincent and the Grenadines                                      1
# Tuvalu                                                                1
# Papua New Guinea                                                      1
#
#                                                     NumknowsPython  \
# Country
# ...

# %%
python_dat2.sort_values(by='pctknowsPython',ascending=False,inplace=True)

# %%
python_dat2.head(50)
# Out:
#                                     country_respondents  NumknowsPython  \
# Country
# Tuvalu                                                1               1
# Brunei Darussalam                                     1               1
# Sierra Leone                                          2               2
# Dominica                                              1               1
# Liechtenstein                                         1               1
# Burundi                                               5               4
# Namibia                                              12               9
# Burkina Faso                                          4               3
# Bahamas                                               7               5
# Qatar                                                29              20
# Liberia                                               3               2
# Saint Lucia                                           3               2
# ...

# %%
python_dat2.loc['Japan']
# Out:
# country_respondents    429.000000
# NumknowsPython         209.000000
# pctknowsPython          48.717949
# Name: Japan, dtype: float64

# %%
python_dat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181 entries, Tuvalu to Papua New Guinea
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country_respondents  181 non-null    int64
#  1   NumknowsPython       181 non-null    int64
#  2   pctknowsPython       181 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 9.7+ KB
