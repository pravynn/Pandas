# %%
import pandas as pd

# %%
data1=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv")

# %%
data1
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
data1.columns=[x.upper() for x in data1.columns]

# %%
data1
# Out:
#        RESPONSEID                                         MAINBRANCH  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               EMPLOYMENT  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1.columns=[x.lower() for x in data1.columns]

# %%
data1
# Out:
#        responseid                                         mainbranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1['mainbranch'].apply(len)
# Out:
# 0        30
# 1        38
# 2        77
# 3        30
# 4        30
#          ..
# 83434    30
# 83435    30
# 83436    30
# 83437    30
# 83438    30
# Name: mainbranch, Length: 83439, dtype: int64

# %%
def update_mainbranch(mainbranch):
    return mainbranch.upper()

# %%
data1['mainbranch'].apply(update_mainbranch)
# Out:
# 0                           I AM A DEVELOPER BY PROFESSION
# 1                   I AM A STUDENT WHO IS LEARNING TO CODE
# 2        I AM NOT PRIMARILY A DEVELOPER, BUT I WRITE CO...
# 3                           I AM A DEVELOPER BY PROFESSION
# 4                           I AM A DEVELOPER BY PROFESSION
#                                ...
# 83434                       I AM A DEVELOPER BY PROFESSION
# 83435                       I AM A DEVELOPER BY PROFESSION
# 83436                       I AM A DEVELOPER BY PROFESSION
# 83437                       I AM A DEVELOPER BY PROFESSION
# 83438                       I AM A DEVELOPER BY PROFESSION
# Name: mainbranch, Length: 83439, dtype: object

# %%
data1['mainbranch']=data1['mainbranch'].apply(update_mainbranch)

# %%
data1
# Out:
#        responseid                                         mainbranch  \
# 0               1                     I AM A DEVELOPER BY PROFESSION
# 1               2             I AM A STUDENT WHO IS LEARNING TO CODE
# 2               3  I AM NOT PRIMARILY A DEVELOPER, BUT I WRITE CO...
# 3               4                     I AM A DEVELOPER BY PROFESSION
# 4               5                     I AM A DEVELOPER BY PROFESSION
# ...           ...                                                ...
# 83434       83435                     I AM A DEVELOPER BY PROFESSION
# 83435       83436                     I AM A DEVELOPER BY PROFESSION
# 83436       83437                     I AM A DEVELOPER BY PROFESSION
# 83437       83438                     I AM A DEVELOPER BY PROFESSION
# 83438       83439                     I AM A DEVELOPER BY PROFESSION
#
#                                               employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1['mainbranch']=data1['mainbranch'].apply(lambda x: x.lower())

# %%
data1
# Out:
#        responseid                                         mainbranch  \
# 0               1                     i am a developer by profession
# 1               2             i am a student who is learning to code
# 2               3  i am not primarily a developer, but i write co...
# 3               4                     i am a developer by profession
# 4               5                     i am a developer by profession
# ...           ...                                                ...
# 83434       83435                     i am a developer by profession
# 83435       83436                     i am a developer by profession
# 83436       83437                     i am a developer by profession
# 83437       83438                     i am a developer by profession
# 83438       83439                     i am a developer by profession
#
#                                               employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1.apply(len)
# Out:
# responseid                      83439
# mainbranch                      83439
# employment                      83439
# country                         83439
# us_state                        83439
# uk_country                      83439
# edlevel                         83439
# age1stcode                      83439
# learncode                       83439
# yearscode                       83439
# yearscodepro                    83439
# devtype                         83439
# orgsize                         83439
# currency                        83439
# comptotal                       83439
# compfreq                        83439
# languagehaveworkedwith          83439
# languagewanttoworkwith          83439
# databasehaveworkedwith          83439
# databasewanttoworkwith          83439
# platformhaveworkedwith          83439
# platformwanttoworkwith          83439
# webframehaveworkedwith          83439
# webframewanttoworkwith          83439
# misctechhaveworkedwith          83439
# ...

# %%
data1.apply(len,axis='columns')
# Out:
# 0        48
# 1        48
# 2        48
# 3        48
# 4        48
#          ..
# 83434    48
# 83435    48
# 83436    48
# 83437    48
# 83438    48
# Length: 83439, dtype: int64

# %%
len(data1['employment'])
# Out:
# 83439

# %%
data1.apply(pd.series)

# %%
# Check the data types of columns in the DataFrame
print(data1.dtypes)

# Convert columns with mixed data types to a consistent data type (e.g., float)
data1['column_name'] = data1['column_name'].astype(float)

# Check for missing values and handle them if necessary
data1.dropna(inplace=True)  # Remove rows with missing values

# Now, you can apply the min function
min_value = data1.apply(lambda x: x.min())
data
data1['Age'] = data1['Age'].astype(float)
print(data1.columns)
# Out:
# responseid                        int64
# mainbranch                        int64
# employment                      float64
# country                           int64
# us_state                        float64
# uk_country                      float64
# edlevel                         float64
# age1stcode                      float64
# learncode                       float64
# yearscode                       float64
# yearscodepro                    float64
# devtype                         float64
# orgsize                         float64
# currency                        float64
# comptotal                       float64
# compfreq                        float64
# languagehaveworkedwith          float64
# languagewanttoworkwith          float64
# databasehaveworkedwith          float64
# databasewanttoworkwith          float64
# platformhaveworkedwith          float64
# platformwanttoworkwith          float64
# webframehaveworkedwith          float64
# ...

# %%
data1
# Out:
#        responseid                                         mainbranch  \
# 0               1                     i am a developer by profession
# 1               2             i am a student who is learning to code
# 2               3  i am not primarily a developer, but i write co...
# 3               4                     i am a developer by profession
# 4               5                     i am a developer by profession
# ...           ...                                                ...
# 83434       83435                     i am a developer by profession
# 83435       83436                     i am a developer by profession
# 83436       83437                     i am a developer by profession
# 83437       83438                     i am a developer by profession
# 83438       83439                     i am a developer by profession
#
#                                               employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1.applymap(len)

# %%
def custom_function(x):
    if isinstance(x, str):
        return len(x)
    elif isinstance(x, (list, tuple)):
        return len(x)
    else:
        return x  # Return the original value for non-string and non-sequence types

data1 = data1.applymap(custom_function)
# Out:
# C:\Users\Otaku\AppData\Local\Temp\ipykernel_13220\3610157443.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data1 = data1.applymap(custom_function)

# %%
data1['UK_COUNTRY'] + ' ' + data1['US_STATE']

# %%
data1
# Out:
#        responseid                                         mainbranch  \
# 0               1                     i am a developer by profession
# 1               2             i am a student who is learning to code
# 2               3  i am not primarily a developer, but i write co...
# 3               4                     i am a developer by profession
# 4               5                     i am a developer by profession
# ...           ...                                                ...
# 83434       83435                     i am a developer by profession
# 83435       83436                     i am a developer by profession
# 83436       83437                     i am a developer by profession
# 83437       83438                     i am a developer by profession
# 83438       83439                     i am a developer by profession
#
#                                               employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1['country_us_state']=data1['COUNTRY']+ ' ' +data1['US_STATE']

# %%
data1
# Out:
#        responseid                                         mainbranch  \
# 0               1                     i am a developer by profession
# 1               2             i am a student who is learning to code
# 2               3  i am not primarily a developer, but i write co...
# 3               4                     i am a developer by profession
# 4               5                     i am a developer by profession
# ...           ...                                                ...
# 83434       83435                     i am a developer by profession
# 83435       83436                     i am a developer by profession
# 83436       83437                     i am a developer by profession
# 83437       83438                     i am a developer by profession
# 83438       83439                     i am a developer by profession
#
#                                               employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1.drop(columns=['UK_COUNTRY','US_STATE'],inplace=True)

# %%
data1
# Out:
#        responseid                                         mainbranch  \
# 0               1                     i am a developer by profession
# 1               2             i am a student who is learning to code
# 2               3  i am not primarily a developer, but i write co...
# 3               4                     i am a developer by profession
# 4               5                     i am a developer by profession
# ...           ...                                                ...
# 83434       83435                     i am a developer by profession
# 83435       83436                     i am a developer by profession
# 83436       83437                     i am a developer by profession
# 83437       83438                     i am a developer by profession
# 83438       83439                     i am a developer by profession
#
#                                               employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
data1.append({'MainBranch':'I am a Actor'},ignore_index=True)

# %%
data1['country_us_state'].str.split(' ',expand=True)

# %%
import pandas as pd

# %%
data1=pd.DataFrame()

# %%
data1=pd.read_csv("D:\Desktop\VS studio\Data\survey_results_public.csv")

# %%
data1.describe(include=['object'])
# Out:
#                             MainBranch          Employment  \
# count                            83439               83323
# unique                               6                   9
# top     I am a developer by profession  Employed full-time
# freq                             58153               53584
#
#                          Country    US_State UK_Country  \
# count                      83439       14920       4418
# unique                       181          55          4
# top     United States of America  California    England
# freq                       15288        2163       3915
#
#                                              EdLevel     Age1stCode LearnCode  \
# count                                          83126          83243     82963
# unique                                             9              9       458
# top     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years    School
# ...

# %%
new_row={'MainBranch':'I am an Actor'}

# %%
data1=data1.append(new_row,ignore_index=True)
data1

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#            a         b         c         d
# 0   0.998533  0.734723  0.845873  0.019419
# 1   0.698169  0.126931  0.798236  0.617268
# 2   0.611166  0.913284  0.831519  0.665086
# 3   0.899639  0.905919  0.345384  0.916786
# 4   0.033844  0.933199  0.490084  0.965163
# 5   0.360696  0.335992  0.881994  0.562553
# 6   0.136205  0.260181  0.372742  0.748854
# 7   0.246319  0.665392  0.763558  0.052268
# 8   0.876116  0.910733  0.176434  0.388685
# 9   0.052707  0.993892  0.692252  0.078130
# 10  0.228500  0.315372  0.204430  0.680971
# 11  0.493841  0.809933  0.741517  0.775384
# 12  0.442994  0.495824  0.552299  0.877804
# 13  0.714615  0.098828  0.263477  0.874570
# 14  0.357909  0.218008  0.976977  0.048573
# 15  0.964181  0.613193  0.248481  0.494026
# 16  0.827060  0.509810  0.237883  0.794861
# 17  0.052273  0.778210  0.496438  0.447522
# 18  0.952461  0.877155  0.349176  0.218819
# 19  0.528044  0.998448  0.658474  0.064513
# 20  0.264418  0.533786  0.388100  0.181431
# ...

# %%
import pandas as pd

# %%
people={'first':['Tony','Steve'],'last':['Stark','Rogers'],'email':['Iranman@marvel.com','cap@avnage.com']}

# %%
di=pd.DataFrame(people)

# %%
di
# Out:
#    first    last               email
# 0   Tony   Stark  Iranman@marvel.com
# 1  Steve  Rogers      cap@avnage.com

# %%
# Create a new DataFrame to append
new_data = pd.DataFrame({'first': ['John']})

# Use the concat function to concatenate the DataFrames
result = pd.concat([di, new_data], ignore_index=True)

# Print the result
print(result)
# Out:
#    first    last               email
# 0   Tony   Stark  Iranman@marvel.com
# 1  Steve  Rogers      cap@avnage.com
# 2   John     NaN                 NaN

# %%
df1=pd.DataFrame({'A':[1,2,3],'B':['a','b','c']})

# %%
df2=pd.DataFrame({'A':[4,5,6],'B':['d','e','f']})

# %%
df_appended = df1.append(df2, ignore_index=True)

# %%
import pandas as pd

df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})

# Concatenate df2 to df1
df_appended = pd.concat([df1, df2], ignore_index=True)

# Display the result
print(df_appended)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  5  7
# 3  6  8

# %%
import pandas as pd

# Create the first dataframe
df1 = pd.DataFrame({'A': [1, 2, 3],
                    'B': ['a', 'b', 'c']})

# Create the second dataframe
df2 = pd.DataFrame({'A': [4, 5, 6],
                    'B': ['d', 'e', 'f']})
# Append the second dataframe to the first dataframe
df_appended = pd.concat([df1,df2], ignore_index=True)
print(df_appended)
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c
# 3  4  d
# 4  5  e
# 5  6  f

# %%
di.drop(index=1)
# Out:
#   first   last               email
# 0  Tony  Stark  Iranman@marvel.com

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.2
