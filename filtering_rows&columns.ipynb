# %%
people={
    "first":["corey","jane","john"],
    "last":["schafer","doe","doe"],
    "email":["coreyMachafer@gmail.com","janedoe@gmail.com","johndoe@gmail.com"]
}

# %%
people['email']
# Out:
# ['coreyMachafer@gmail.com', 'janedoe@gmail.com', 'johndoe@gmail.com']

# %%
import pandas as pd

# %%
af=pd.DataFrame(people)

# %%
af
# Out:
#    first     last                    email
# 0  corey  schafer  coreyMachafer@gmail.com
# 1   jane      doe        janedoe@gmail.com
# 2   john      doe        johndoe@gmail.com

# %%
ft=(af['last'] == 'doe') | (af['first'] =='john')

# %%
af.loc[~ft,'email']
# Out:
# 0    coreyMachafer@gmail.com
# Name: email, dtype: object

# %%
af.shape
# Out:
# (3, 3)

# %%
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   3 non-null      object
#  1   last    3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   3 non-null      object
#  1   last    3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
import pandas as pd

# %%
survey=pd.read_csv('D:\Desktop\VS studio\Data\survey_results_public.csv',index_col='ResponseId')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
survey
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
high_one=(survey['ConvertedCompYearly'] > 70000 )

# %%
survey.loc[high_one]
# Out:
#                                                    MainBranch  \
# ResponseId
# 13                             I am a developer by profession
# 19          I am not primarily a developer, but I write co...
# 25                             I am a developer by profession
# 27          I am not primarily a developer, but I write co...
# 32                             I am a developer by profession
# ...                                                       ...
# 83431                          I am a developer by profession
# 83433                          I am a developer by profession
# 83435                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
#
#                      Employment                   Country    US_State  \
# ResponseId
# 13           Employed full-time                   Germany         NaN
# ...

# %%
survey.loc[high_one, ['Country', 'LanguageHaveWorkedWith', 'OpSys', 'ConvertedCompYearly']]
# Out:
#                              Country  \
# ResponseId
# 13                           Germany
# 19                         Singapore
# 25                           Germany
# 27                       Switzerland
# 32                            Israel
# ...                              ...
# 83431       United States of America
# 83433                         Canada
# 83435       United States of America
# 83437       United States of America
# 83438                         Canada
#
#                                        LanguageHaveWorkedWith        OpSys  \
# ResponseId
# 13                                       C;C++;Java;Perl;Ruby  Linux-based
# 19                                                 C++;Python  Linux-based
# 25          C++;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Ty...  Linux-based
# 27                                                 C++;Python  Linux-based
# 32                Bash/Shell;Go;Java;Node.js;Python;Scala;SQL        MacOS
# ...

# %%
survey
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
countries=['Canada','Brazil','Benin','Austria','slovakia']
flt=survey['Country'].isin(countries)

# %%
survey.loc[flt,'Country']
# Out:
# ResponseId
# 4        Austria
# 18        Canada
# 20        Brazil
# 46        Brazil
# 68        Canada
#           ...
# 83433     Canada
# 83434     Brazil
# 83436      Benin
# 83438     Canada
# 83439     Brazil
# Name: Country, Length: 6089, dtype: object

# %%
survey['Country']
# Out:
# ResponseId
# 1                                                 Slovakia
# 2                                              Netherlands
# 3                                       Russian Federation
# 4                                                  Austria
# 5        United Kingdom of Great Britain and Northern I...
#                                ...
# 83435                             United States of America
# 83436                                                Benin
# 83437                             United States of America
# 83438                                               Canada
# 83439                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
survey['MainBranch']
# Out:
# ResponseId
# 1                           I am a developer by profession
# 2                   I am a student who is learning to code
# 3        I am not primarily a developer, but I write co...
# 4                           I am a developer by profession
# 5                           I am a developer by profession
#                                ...
# 83435                       I am a developer by profession
# 83436                       I am a developer by profession
# 83437                       I am a developer by profession
# 83438                       I am a developer by profession
# 83439                       I am a developer by profession
# Name: MainBranch, Length: 83439, dtype: object

# %%
survey['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
lang=survey['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
survey.loc[lang,'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                                        JavaScript;Python
# 3                                 Assembly;C;Python;R;Rust
# 5                           Bash/Shell;HTML/CSS;Python;SQL
# 6        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                              C++;Python
#                                ...
# 83430               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                   Groovy;Java;Python
# 83438                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
survey.loc[83430:83439]
# Out:
#                                 MainBranch  \
# ResponseId
# 83430          I code primarily as a hobby
# 83431       I am a developer by profession
# 83432       I am a developer by profession
# 83433       I am a developer by profession
# 83434       I am a developer by profession
# 83435       I am a developer by profession
# 83436       I am a developer by profession
# 83437       I am a developer by profession
# 83438       I am a developer by profession
# 83439       I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 83430                      Not employed, but looking for work
# 83431                                      Employed full-time
# 83432       Independent contractor, freelancer, or self-em...
# 83433                                      Employed full-time
# 83434       Independent contractor, freelancer, or self-em...
# 83435                                      Employed full-time
# ...

# %%
survey['Country']
# Out:
# ResponseId
# 1                                                 Slovakia
# 2                                              Netherlands
# 3                                       Russian Federation
# 4                                                  Austria
# 5        United Kingdom of Great Britain and Northern I...
#                                ...
# 83435                             United States of America
# 83436                                                Benin
# 83437                             United States of America
# 83438                                               Canada
# 83439                                               Brazil
# Name: Country, Length: 83439, dtype: object
